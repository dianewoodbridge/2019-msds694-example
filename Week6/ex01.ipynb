# %%
# %%help
# Out:
# <table>
#   <tr>
#     <th>Magic</th>
#     <th>Example</th>
#     <th>Explanation</th>
#   </tr>
#   <tr>
#     <td>info</td>
#     <td>%%info</td>
#     <td>Outputs session information for the current Livy endpoint.</td>
#   </tr>
#   <tr>
#     <td>cleanup</td>
#     <td>%%cleanup -f</td>
#     <td>Deletes all sessions for the current Livy endpoint, including this notebook's session. The force flag is mandatory.</td>
#   </tr>
#   <tr>
#     <td>delete</td>
#     <td>%%delete -f -s 0</td>
#     <td>Deletes a session by number for the current Livy endpoint. Cannot delete this kernel's session.</td>
#   </tr>
#   <tr>
#     <td>logs</td>
#     <td>%%logs</td>
#     <td>Outputs the current session's Livy logs.</td>
#   </tr>
#   <tr>
#     <td>configure</td>
#     <td>%%configure -f<br/>{"executorMemory": "1000M", "executorCores": 4}</td>
#     <td>Configure the session creation parameters. The force flag is mandatory if a session has already been
# ...

# %%
# %%info
# Out:
# Current session configs: <tt>{'conf': {'spark.pyspark.python': 'python3', 'spark.pyspark.virtualenv.enabled': 'true', 'spark.pyspark.virtualenv.type': 'native', 'spark.pyspark.virtualenv.bin.path': '/usr/bin/virtualenv'}, 'kind': 'pyspark'}</tt><br>
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>1</td><td>application_1574343938747_0003</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-25-197.us-east-2.compute.internal:20888/proxy/application_1574343938747_0003/">Link</a></td><td><a target="_blank" href="http://ip-172-31-18-40.us-east-2.compute.internal:8042/node/containerlogs/container_1574343938747_0003_01_000001/livy">Link</a></td><td></td></tr></table>

# %%
from pyspark import SparkContext
sc = SparkContext.getOrCreate()
# Out:
# VBox()
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>7</td><td>application_1574343938747_0009</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-25-197.us-east-2.compute.internal:20888/proxy/application_1574343938747_0009/">Link</a></td><td><a target="_blank" href="http://ip-172-31-18-40.us-east-2.compute.internal:8042/node/containerlogs/container_1574343938747_0009_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
numbers  = sc.parallelize([1,2,3,4])
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
numbers.glom().collect()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# [[], [1], [2], [], [3], [4]]

# %% [markdown]
# ## Read from S3

# %%
rdd = sc.textFile("s3n://usfca-msan694/README.md")
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
rdd.first()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# '# Apache Spark'

# %% [markdown]
# ## Write to S3

# %%
numbers.saveAsTextFile("s3n://usfca-msan694/numbers")
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# An error occurred while calling o116.saveAsTextFile.
# : org.apache.hadoop.mapred.FileAlreadyExistsException: Output directory s3n://usfca-msan694/numbers already exists
# 	at org.apache.hadoop.mapred.FileOutputFormat.checkOutputSpecs(FileOutputFormat.java:131)
# 	at org.apache.spark.internal.io.HadoopMapRedWriteConfigUtil.assertConf(SparkHadoopWriter.scala:289)
# 	at org.apache.spark.internal.io.SparkHadoopWriter$.write(SparkHadoopWriter.scala:71)
# 	at org.apache.spark.rdd.PairRDDFunctions$$anonfun$saveAsHadoopDataset$1.apply$mcV$sp(PairRDDFunctions.scala:1096)
# 	at org.apache.spark.rdd.PairRDDFunctions$$anonfun$saveAsHadoopDataset$1.apply(PairRDDFunctions.scala:1094)
# 	at org.apache.spark.rdd.PairRDDFunctions$$anonfun$saveAsHadoopDataset$1.apply(PairRDDFunctions.scala:1094)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# ...

# %% [markdown]
# ## Configure EMR - Should go at the beginning

# %%
# %%configure -f
# {"name":"week7-ex01", "executorMemory": "4G", "executorCores": 4, "driverMemory" : "2G" }
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>10</td><td>application_1574343938747_0012</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-25-197.us-east-2.compute.internal:20888/proxy/application_1574343938747_0012/">Link</a></td><td><a target="_blank" href="http://ip-172-31-18-40.us-east-2.compute.internal:8042/node/containerlogs/container_1574343938747_0012_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# Current session configs: <tt>{'name': 'week7-ex01', 'executorMemory': '4G', 'executorCores': 4, 'driverMemory': '2G', 'kind': 'pyspark'}</tt><br>
# <table>
# ...
