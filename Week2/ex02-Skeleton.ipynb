# %%
import pyspark
import os

sc = pyspark.SparkContext(appName='day2_ex02').getOrCreate()

# %% [markdown]
# # What is Spark Context?

# %%
sc

# %% [markdown]
# # Read lines from README.md and store in 8 partitions

# %% [markdown]
# ###### TODO : Change the number of partitions.

# %% [markdown]
# ### Try textFile()

# %%
lines =

# %% [markdown]
# ### getNumPartitions()

# %%
lines.

# %% [markdown]
# ### Difference between .collect() and .glom().collect()?

# %%
lines.

# %%
lines.

# %% [markdown]
# ### Try parallelize()

# %%
lines_2

# %%
lines_2.

# %%
lines_2.

# %% [markdown]
# # Saving distributed data

# %% [markdown]
# ### saveAsTextFile(folder) and read from folder

# %%
# Make sure to delete this folder if existing.
lines_2.

# %%
lines_2_from_part_files

# %%
lines_2_from_part_files.  # part-XX files are read as a single file.

# %% [markdown]
# # Stop the spark context
